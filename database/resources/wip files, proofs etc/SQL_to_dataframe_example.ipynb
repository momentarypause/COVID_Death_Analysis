# %%
from sqlalchemy import create_engine
import psycopg2

import pandas as pd

# %%
db_string = f"postgresql://postgres:postgres@127.0.0.1:5432/COVID_MSU"
engine = create_engine(db_string)

cdc_analysis_df = pd.read_sql_query('''SELECT * FROM cdc_df_regions''', con=engine)

# %%
cdc_analysis_df.head()
# Out:
#    index  Unnamed: 0 date_onset state  st_code      county     fips  \
# 0    128         128 2021-08-01    PA       42  WASHINGTON  42125.0
# 1    129         129 2021-08-01    PA       42  WASHINGTON  42125.0
# 2    287         287 2020-04-01    TN       47      SHELBY  47157.0
# 3    378         378 2020-10-01    TN       47    DAVIDSON  47037.0
# 4    470         470 2022-02-01    KS       20       RILEY  20161.0
#
#         age_range     sex   race            ethnicity  case_positive_specimen  \
# 0    0 - 17 years  Female  White  Non-Hispanic/Latino                       1
# 1    0 - 17 years  Female  White  Non-Hispanic/Latino                       1
# 2  18 to 49 years  Female  Black  Non-Hispanic/Latino                       1
# 3  50 to 64 years    Male  Black  Non-Hispanic/Latino                       0
# 4    0 - 17 years  Female  White  Non-Hispanic/Latino                       0
#
#               current_status symptom_status  hosp_yn  icu_yn  death_yn  \
# ...

# %%
output = 'cdc_df_regions_11_2.csv'
cdc_analysis_df.to_csv(output)
