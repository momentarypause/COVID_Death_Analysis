# %%
from sqlalchemy import create_engine
import psycopg2

import pandas as pd

# %%
db_string = f"postgresql://postgres:postgres@127.0.0.1:5432/test"
engine = create_engine(db_string)

cdc_analysis_df = pd.read_sql_query('''SELECT * FROM pretend_cleaned_cdc_data''', con=engine)

# %%
cdc_analysis_df.head()
# Out:
#    index res_state state_fips_code       res_county county_fips_code  \
# 0      2        MD              24  PRINCE GEORGE'S            24033
# 1      7        NJ              34        MIDDLESEX            34023
# 2      8        NC              37             WAKE            37183
# 3     17        NJ              34         MONMOUTH            34025
# 4     24        NY              36             ERIE            36029
#
#         age_group     sex   race            ethnicity  \
# 0  18 to 49 years    Male  Asian  Non-Hispanic/Latino
# 1    0 - 17 years  Female  White              Missing
# 2  18 to 49 years    Male  Asian  Non-Hispanic/Latino
# 3  18 to 49 years  Female  White  Non-Hispanic/Latino
# 4    0 - 17 years  Female  Black              Unknown
#
#               current_status  ...  hosp_yn   icu_yn death_yn  \
# 0              Probable Case  ...       No  Missing       No
# 1              Probable Case  ...       No  Missing       No
# 2  Laboratory-confirmed case  ...  Unknown  Unknown       No
# 3  Laboratory-confirmed case  ...      Yes  Missing       No
# 4  Laboratory-confirmed case  ...  Missing  Missing       No
#
#   case_positive_specimen case_onset_interval case_onset case_onset_month  \
# 0                   None                   0 2020-10-01               10
# 1                      0                None 2021-12-01               12
# 2                      0                None 2022-01-01               01
# 3                      0                   0 2021-03-01               03
# 4                   None                None 2020-12-01               12
#
#   case_onset_year     age_group_c death_yn_b
# 0            2020  18 to 49 years       True
# 1            2021    0 - 17 years       True
# 2            2022  18 to 49 years       True
# 3            2021  18 to 49 years       True
# 4            2020    0 - 17 years       True
#
# [5 rows x 21 columns]
